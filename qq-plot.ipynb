# %%
#https://chat.openai.com/share/e351c08d-9884-4d8b-83a3-e150aa8e645b
#https://towardsdatascience.com/significance-of-q-q-plots-6f0c6e31c626#:~:text=Quantile%2DQuantile%20plot%
#20or%20Q%2DQ,you%20are%20testing%20it%20against.
import matplotlib.pyplot as plt
import numpy as np

# Generate a simple dataset
data = np.random.randn(100)

# %%
data
# Out:
# array([-1.55427665,  0.02754511, -0.87745639,  1.10099443, -0.85929903,
#         0.05413259,  0.83490765,  1.5469543 , -1.32239203, -1.01422411,
#        -1.61178644, -0.11900295,  0.60834355, -1.07855936, -0.04523954,
#         1.77477807,  0.59082255, -0.57166654,  0.49234662, -1.42474796,
#        -0.68913907, -2.89512377,  1.42368239, -1.09182476,  0.26147615,
#         0.60677506, -0.63886916, -0.51374976,  0.79778018, -1.97508687,
#        -0.94767796,  1.31630984, -0.84255445, -1.56357121,  0.41095482,
#        -1.55096828, -0.17403364, -1.44565927, -0.51447212,  1.44069134,
#        -1.13594068, -1.4069049 , -0.03303247,  0.48489419,  0.12980004,
#         0.87391747,  1.93320842, -0.37200804,  0.29907466, -0.42994462,
#         0.5095405 , -1.36823073,  1.13775968,  0.01204496,  1.34610516,
#         0.02030268,  0.13110606,  1.20076783, -0.75601762,  0.1434878 ,
#        -1.44849006, -1.60707791,  1.98061166, -1.05314955,  0.22425024,
# ...

# %%
# Create a qq plot
plt.figure(figsize=(8, 6))
plt.scatter(sorted(data), np.linspace(0, 1, len(data)))
plt.xlabel("Theoretical Quantiles")
plt.ylabel("Sample Quantiles")
plt.title("QQ Plot of Random Data")
plt.grid(True)
plt.show()

# %%
##analytics vidhiya

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
# %matplotlib inline

np.random.seed(100) #for reproducibility

# %%
# Generate 200 random normal data points with mean=0, standard_deviation=0.1
# Documentation: https://numpy.org/doc/stable/reference/random/generated/numpy.random.normal.html
random_normal_datapoints = pd.Series(np.random.normal(0, 0.1, 200))

# %%
random_normal_datapoints
# Out:
# 0     -0.174977
# 1      0.034268
# 2      0.115304
# 3     -0.025244
# 4      0.098132
#          ...
# 195    0.064917
# 196   -0.017478
# 197    0.101726
# 198   -0.059998
# 199    0.157617
# Length: 200, dtype: float64

# %%
random_normal_datapoints.describe().T
# Out:
# count    200.000000
# mean      -0.008721
# std        0.102070
# min       -0.297332
# 25%       -0.077425
# 50%       -0.009201
# 75%        0.068770
# max        0.229865
# dtype: float64

# %%
# Lets plot the data points along with its KDE to see how it looks
fig, ax = plt.subplots()
random_normal_datapoints.plot.kde(ax=ax, legend=False, title='A random normal distrubution with mean 0 and SD 0.1')
random_normal_datapoints.plot.hist(density=True, ax=ax)
ax.set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
random_normal_datapoints.plot()
# Out:
# <AxesSubplot: >

# %%
# Plot the Q-Q plot to graphically check for the hypothesis
# https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.probplot.html
res = stats.probplot(random_normal_datapoints, plot=plt)
plt.show()

# %%
# generating 200 uniformly distributed datapoints between the range of -1 and 0
# Documentation : https://numpy.org/doc/stable/reference/random/generated/numpy.random.uniform.html
random_uniform_datapoints = pd.Series(np.random.uniform(-1,1,200))

# %%
# Lets plot the data points along with its KDE to see how it looks
fig, ax = plt.subplots()
random_uniform_datapoints.plot.kde(ax=ax, legend=False, title='A random uniform distribution between range -1 and 1')
random_uniform_datapoints.plot.hist(density=True, ax=ax)
ax.set_ylabel('Frequency')
plt.xlim((-1,1))
# Out:
# (-1.0, 1.0)

# %%
# Plot the Q-Q plot to graphically check for the hypothesis
res = stats.probplot(random_uniform_datapoints, plot=plt)
plt.show()

# %%
# Example data
mean_score = 75
std_deviation = 10
your_score = 80

# Calculate Z-score
z_score = (your_score - mean_score) / std_deviation

print(f"Your Z-score is: {z_score}")
# Out:
# Your Z-score is: 0.5

# %%
import numpy as np

test_scores = [85, 90, 88, 78, 92, 87, 80, 95, 82, 89]

mean_score = np.mean(test_scores)
std_deviation = np.std(test_scores)

print(f"Mean: {mean_score}")
print(f"Standard Deviation: {std_deviation}")
# Out:
# Mean: 86.6
# Standard Deviation: 5.10294032886923

# %%
z_scores = [(x - mean_score) / std_deviation for x in test_scores]

print("Z-Scores:")
for i, z in enumerate(z_scores):
    print(f"Data Point {i+1}: {z:.2f}")
# Out:
# Z-Scores:
# Data Point 1: -0.31
# Data Point 2: 0.67
# Data Point 3: 0.27
# Data Point 4: -1.69
# Data Point 5: 1.06
# Data Point 6: 0.08
# Data Point 7: -1.29
# Data Point 8: 1.65
# Data Point 9: -0.90
# Data Point 10: 0.47

# %%
z_scores
# Out:
# [-0.31354472066784705,
#  0.6662825314191785,
#  0.2743516305843683,
#  -1.685302873589683,
#  1.0582134322539887,
#  0.07838618016696317,
#  -1.2933719727548727,
#  1.646109783506204,
#  -0.9014410719200624,
#  0.4703170810017734]

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import probplot

# Example test scores
#test_scores = [85, 90, 88, 78, 92, 87, 80, 95, 82, 89]

# Create Q-Q plot
probplot(test_scores, dist="norm", plot=plt)
plt.title('Q-Q Plot for Test Scores')
plt.xlabel('Theoretical Quantiles')
plt.ylabel('Observed Quantiles')
plt.show()

# %%
a = z_scores.sort()

# %%
print(a)
# Out:
# None

# %%
z_scores
# Out:
# [-1.685302873589683,
#  -1.2933719727548727,
#  -0.9014410719200624,
#  -0.31354472066784705,
#  0.07838618016696317,
#  0.2743516305843683,
#  0.4703170810017734,
#  0.6662825314191785,
#  1.0582134322539887,
#  1.646109783506204]

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import shapiro, probplot

# Example dataset
data = [85, 90, 88, 78, 92, 87, 80, 95, 82, 89]

# Shapiro-Wilk test
stat, p_value = shapiro(data)
print(f'Shapiro-Wilk Test: Statistics={stat}, p-value={p_value}')

# Q-Q plot
probplot(data, dist="norm", plot=plt)
plt.title('Q-Q Plot for Test Scores')
plt.xlabel('Theoretical Quantiles')
plt.ylabel('Observed Quantiles')
plt.show()

# KDE plot
sns.kdeplot(data, shade=True, color="blue")
plt.title('KDE Plot for Test Scores')
plt.xlabel('Test Scores')
plt.ylabel('Density')
plt.show()
# Out:
# Shapiro-Wilk Test: Statistics=0.9765804409980774, p-value=0.9442809820175171
# /var/folders/10/52b3g9k53sj053mkdsbvq74c0000gp/T/ipykernel_17365/2870656515.py:21: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data, shade=True, color="blue")

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import probplot

# Example dataset
data = [85, 90, 88, 78, 92, 87, 80, 95, 82, 89]

# Q-Q plot
probplot(data, dist="norm", plot=plt)
plt.title('Q-Q Plot for Test Scores')
plt.xlabel('Theoretical Quantiles')
plt.ylabel('Observed Quantiles')
plt.show()

# KDE plot
sns.kdeplot(data, shade=True, color="blue")
plt.title('KDE Plot for Test Scores')
plt.xlabel('Test Scores')
plt.ylabel('Density')
plt.show()

# Tukey's Fences
q1 = np.percentile(data, 25)
q3 = np.percentile(data, 75)
iqr = q3 - q1

lower_fence = q1 - 1.5 * iqr
upper_fence = q3 + 1.5 * iqr

outliers = [x for x in data if x < lower_fence or x > upper_fence]
print(f'Tukey\'s Fences: Lower Fence={lower_fence}, Upper Fence={upper_fence}, Potential Outliers={outliers}')
# Out:
# /var/folders/10/52b3g9k53sj053mkdsbvq74c0000gp/T/ipykernel_17365/1538487039.py:17: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data, shade=True, color="blue")
# Tukey's Fences: Lower Fence=72.25, Upper Fence=100.25, Potential Outliers=[]
